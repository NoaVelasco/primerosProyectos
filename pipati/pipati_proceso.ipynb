# %% [markdown]
# # Piedra, papel, tijeras
#
# Voy a ir desarrollando mi primer proyecto. Lo que quiero es jugar a piedra-papel-tijeras con la máquina al mejor de 3, pero me apetecía hacer un poco de trampitas. Se dice que hay una ligera tendencia de más a sacar tijeras en la primera ronda, tal vez porque nos sale más fácilmente el gesto o porque coincide cuando decimos "tijeras". Así que quería dar más porcentaje a piedra>tijera>papel. No será lo mismo en un programa, pero quería probar.

# %%
var1 = input("Elige:")

x = var1.lower()

print(x)
# Out:
# dfsffsdsflnnlknkln

# %%
from random import randint
from random import random

piedra = "piedra"
papel = "papel"
tijeras = "tijeras"
pipati = (piedra, papel, tijeras)


print("¿Te apetece jugar a piedra-papel-tijeras?")
print("Vale, pues a la de tres...:")
print("Piedra...")
print("Papel...")
print("¡Tijeras!")

pptAlea = randint(0,100)
if pptAlea < 40:
    machinInput = piedra
elif pptAlea > 75:
    machinInput = papel
else:
    machinInput = tijeras

userElige = input()
userInput = userElige.lower()

print("Yo he elegido " + machinInput + ".")

print("Y tú has elegido " + userInput + ".")

if userInput != machinInput:
    if machinInput == piedra and userInput == papel:
        print("Has ganado")
    elif machinInput == piedra and userInput == tijeras:
        print("Has perdido")
    elif machinInput == papel and userInput == tijeras:
        print("Has ganado")
    elif machinInput == papel and userInput == piedra:
        print("Has perdido")
    elif machinInput == tijeras and userInput == piedra:
        print("¡Has ganado!")
    elif machinInput == tijeras and userInput == papel:
        print("¡Has perdido!")

else:
    print("¡Empate!")

# %% [markdown]
# Hasta aquí tenía una versión funcional de una sola partida. Esta es una versión recursiva con puntuación:

# %%
from random import randint

print("¿Te apetece jugar a piedra-papel-tijeras?")
print("Vale, pues a la de tres...:")
print("Piedra...")
print("Papel...")
print("¡Tijeras!")

piedra = "piedra"
papel = "papel"
tijeras = "tijeras"
userCont = 0
machinCont = 0

pptAlea = randint(0,100)
if pptAlea < 40:
    machinInput = piedra
elif pptAlea > 75:
    machinInput = papel
else:
    machinInput = tijeras

userElige = input()
userInput = userElige.lower()


print("Yo he elegido " + machinInput + ".")

print("Y tú has elegido " + userInput + ".")

if userInput != machinInput:
    if machinInput == piedra and userInput == papel:
        print("Has ganado")
        userCont += 1
    elif machinInput == piedra and userInput == tijeras:
        print("Has perdido")
        machinCont += 1
    elif machinInput == papel and userInput == tijeras:
        print("Has ganado")
        userCont += 1
    elif machinInput == papel and userInput == piedra:
        print("Has perdido")
        machinCont += 1
    elif machinInput == tijeras and userInput == piedra:
        print("Has ganado")
        userCont += 1
    elif machinInput == tijeras and userInput == papel:
        print("Has perdido")
        machinCont += 1

else:
    print("Empate")  
       

print("¿Jugamos al mejor de tres?")

def partida():
    global userCont
    global machinCont
    print("Piedra...")
    print("Papel...")
    print("¡Tijeras!")

    pptAlea = randint(0,2)
    if pptAlea == 0:
        machinInput = piedra
    elif pptAlea == 1:
        machinInput = papel
    else:
        machinInput = tijeras

    userElige = input("Elige:")
    userInput = userElige.lower()

    print("Yo he elegido " + machinInput + ".")

    print("Y tú has elegido " + userInput + ".")

    if userInput != machinInput:
        if machinInput == piedra and userInput == papel:
            print("Has ganado")
            userCont += 1
        elif machinInput == piedra and userInput == tijeras:
            print("Has perdido")
            machinCont += 1
        elif machinInput == papel and userInput == tijeras:
            print("Has ganado")
            userCont += 1
        elif machinInput == papel and userInput == piedra:
            print("Has perdido")
            machinCont += 1
        elif machinInput == tijeras and userInput == piedra:
            print("Has ganado")
            userCont += 1
        elif machinInput == tijeras and userInput == papel:
            print("Has perdido")
            machinCont += 1

    else:
        print("Empate")

    print(f"Yo he ganado: {machinCont}.")
    print(f"Tú has ganado: {userCont}.")
    

while abs(userCont - machinCont) != 3:
    partida()

else:
    if userCont == (machinCont + 3):
        print("Está bien, no hay quien pueda contigo.")
    else:
        print("Has jugado bien. Para un ser humano, jijiji.")

# %% [markdown]
# Aquí van algunas pruebas preliminares hasta que descubrí que desde la función no podía llamar a las variables (contadores) globales (creía que eso era solo cuando comparten el mismo nombre).

# %%
x=3
y=6
print(abs(x-y))

while abs(userCont - machinCont) != 3:
    partida()

if userCont == (machinCont + 3):
    print("Está bien, no hay quien pueda contigo.")
else:
    print("Has jugado bien. Para un ser humano, jijiji.")
# Out:
# 3

# %%
from random import randint

piedra = "piedra"
papel = "papel"
tijeras = "tijeras"
  

print("¿Jugamos?")

def partida():
    print("Piedra...")
    print("Papel...")
    print("¡Tijeras!")

    pptAlea = randint(0,2)
    if pptAlea == 0:
        machinInput = piedra
    elif pptAlea == 1:
        machinInput = papel
    else:
        machinInput = tijeras

    userElige = input("Elige:")
    userInput = userElige.lower()

    print("Yo he elegido " + machinInput + ".")
    print("Y tú has elegido " + userInput + ".")

    userCont = 0
    machinCont = 0

    if userInput != machinInput:
        if machinInput == piedra and userInput == papel:
            print("Has ganado")
            userCont = userCont+1
            comprobante(machinCont, userCont)
        elif machinInput == piedra and userInput == tijeras:
            print("Has perdido")
            machinCont = machinCont+1
            comprobante(machinCont, userCont)
        elif machinInput == papel and userInput == tijeras:
            print("Has ganado")
            userCont = userCont+1
            comprobante(machinCont, userCont)
        elif machinInput == papel and userInput == piedra:
            print("Has perdido")
            machinCont = machinCont+1
            comprobante(machinCont, userCont)
        elif machinInput == tijeras and userInput == piedra:
            print("Has ganado")
            userCont = userCont+1
            comprobante(machinCont, userCont)
        elif machinInput == tijeras and userInput == papel:
            print("Has perdido")
            machinCont = machinCont+1
            comprobante(machinCont, userCont)
    else:
        print("Empate")
        comprobante(machinCont, userCont)
    
def comprobante(machinCont, userCont):
    print("Yo he ganado: ", str(machinCont), ".")
    print("Tú has ganado: ", str(userCont), ".")  
        
    if abs(userCont - machinCont) != 3:
        partida()
    elif userCont == (machinCont + 3):
            print("Está bien, no hay quien pueda contigo.")
    elif machinCont == (userCont + 3):
            print("Has jugado bien. Para un ser humano, jijiji.")
        
        
partida()

# %% [markdown]
# Esta era una versión simplificada en la que había quitado el inicio tramposo. Creo que es funcional.

# %%
from random import randint

piedra = "piedra"
papel = "papel"
tijeras = "tijeras"
userCont = 0
machinCont = 0


print("¿Jugamos?")

def partida():
    
    global userCont
    global machinCont
    
    print("Piedra...")
    print("Papel...")
    print("¡Tijeras!")

    pptAlea = randint(0,2)
    if pptAlea == 0:
        machinInput = piedra
    elif pptAlea == 1:
        machinInput = papel
    else:
        machinInput = tijeras

    userElige = input("Elige:")
    userInput = userElige.lower()

    print("Yo he elegido " + machinInput + ".")
    print("Y tú has elegido " + userInput + ".")

    
    if userInput != machinInput:
        if machinInput == piedra and userInput == papel:
            print("¡Has ganado!")
            userCont = userCont+1
            comprobante(machinCont, userCont)
        elif machinInput == piedra and userInput == tijeras:
            print("¡Has perdido!")
            machinCont = machinCont+1
            comprobante(machinCont, userCont)
        elif machinInput == papel and userInput == tijeras:
            print("¡Has ganado!")
            userCont = userCont+1
            comprobante(machinCont, userCont)
        elif machinInput == papel and userInput == piedra:
            print("¡Has perdido!")
            machinCont = machinCont+1
            comprobante(machinCont, userCont)
        elif machinInput == tijeras and userInput == piedra:
            print("¡Has ganado!")
            userCont = userCont+1
            comprobante(machinCont, userCont)
        elif machinInput == tijeras and userInput == papel:
            print("¡Has perdido!")
            machinCont = machinCont+1
            comprobante(machinCont, userCont)
    else:
        print("Empate")
        comprobante(machinCont, userCont)
    

def comprobante(machinCont, userCont):
    print(f"Yo he ganado: {machinCont}.")
    print(f"Tú ¡has ganado!: {userCont}.")
        
    if abs(userCont - machinCont) != 3:
        partida()
    elif userCont == (machinCont + 3):
            print("Está bien, no hay quien pueda contigo.")
    elif machinCont == (userCont + 3):
            print("Has jugado bien. Para un ser humano, jijiji.")
        
        
partida()

# %% [markdown]
# Antes de eso hice esta versión aún más simplificada. De hecho, la función no juega a pi-pa-ti, sino que directamente juega sola para mostrar simulaciones. De nuevo, funciona gracias a la llamada global de variables.

# %%
from random import randint

userCont = 0
machinCont = 0  


print("¿Jugamos?")

def jugar():
    global userCont
    global machinCont
    print("yo: ", machinCont, "\nTú: ", userCont)

    pptAlea = randint(0,1)
    if pptAlea == 0:
        machinCont = machinCont+1
        x=input("Has perdido. ¿Otra vez?")

    else:
        userCont = userCont + 1
        print("Has ganado")

for x in range(0,5):
    jugar()
# Out:
# ¿Jugamos?
# yo:  0
# Tú:  0
# yo:  1
# Tú:  0
# Has ganado
# yo:  1
# Tú:  1
# Has ganado
# yo:  1
# Tú:  2
# yo:  2
# Tú:  2
# Has ganado

# %% [markdown]
# Lo siguiente que quiero hacer es añadir una advertencia cuando se escriba mal, obligando a teclear de nuevo. De momento quiero pensarlo sin tener que crear un bucle while e indentando toooodo el contenido. Es posible que ni siquiera eso funcione. Así que es buen momento para incluir aquí el código de otras personas. ;)
#
# Este de Louis tiene algo que me gustó, que era algo que tenía en mente al principio: la tupla de opciones. El siguiente tiene otra cosa que se me ocurrió: los diccionarios.

# %%
# Created by Louis

#Rock Paper Scissors
from random import randint as r

hand = ('rock', 'paper', 'scissors')
outcome = ('draws', 'wins', 'loses')
score, num, end = [0, 0, 0], 0, 5

print(f'First to {end} wins')

while max(score[1:]) < end:
    player1, player2, num = r(0, 2), r(0, 2), num+1
    result = player1-player2
    score[result] += 1
    print(
        f'{num:>2}: {hand[player1].capitalize()} {outcome[result]} vs. {hand[player2]}. {score[1:]}')

print(f'{"="*40}\nPLAYER{(1 if score[1]>=end else 2)} WINS!\n{"="*40}')

# %% [markdown]
# Luego estuve rehaciendo el código de Kylie a partir de un vídeo de YT (aunque luego tenía el código entero en Github, claro).
# Tenía un sistema de "el mejor de 3" o los que quisieras configurar.
# Sigo teniendo el problema de programar una forma de soportar inputs erróneos.

# %%
# Created by Agata Polejowska

# Please enter: rock, scissors or paper

import random

possibilities = {'rock': 1, 'scissors': 2, 'paper': 3}

player = input().lower()

if not (player == 'rock' or player == 'scissors' or player == 'paper'):
    print('Incorrect input. ')
    exit()

num = possibilities.get(player)
computer = random.choice(list(possibilities.keys()))
num_computer = possibilities[computer]


print('You: {} - {}  |  Computer: {} - {}'.format(num, player, num_computer, computer))


result = num - num_computer
if result in [-1, 2]:
    print(' \n You win! ')
elif result in [-2, 1]:
    print(' \n Computer wins. ')
else:
    print(' \n It\'s a draw. ')

# %% [markdown]
# Aquí tengo mi versión terminada a `220225`, que incluye un sistema que impide que se crashee con un mal input.

# %%
from random import randint  # También se puede hacer con random.choice()

print("¿Te apetece jugar a piedra-papel-tijeras?")
print("Vale, pues a la de tres...:")
print("Piedra...")
print("Papel...")
print("¡Tijeras!")

piedra = "piedra"
papel = "papel"
tijeras = "tijeras"

# En el futuro, mi intención es prescindir de estas 3 variables y tirar de la siguiente tupla:

opciones = [piedra, papel, tijeras]
userCont = 0
machinCont = 0

pptAlea = randint(0, 100)
if pptAlea < 40:
    machinInput = piedra
elif pptAlea > 75:
    machinInput = papel
else:
    machinInput = tijeras

# Reconozco que he hecho trampas. Se dice que la primera jugada tiende más a ser tijeras.

userElige = input(">>>")
userInput = userElige.lower()

while userInput not in opciones:
    print("Escríbelo otra vez, por favor.")
    userInput = input(">>>").lower()

print("Yo he elegido " + machinInput + ".")
print("Y tú has elegido " + userInput + ".")

if userInput != machinInput:
    if machinInput == piedra and userInput == papel:
        print("Has ganado")
        userCont += 1
    elif machinInput == piedra and userInput == tijeras:
        print("Has perdido")
        machinCont += 1
    elif machinInput == papel and userInput == tijeras:
        print("Has ganado")
        userCont += 1
    elif machinInput == papel and userInput == piedra:
        print("Has perdido")
        machinCont += 1
    elif machinInput == tijeras and userInput == piedra:
        print("Has ganado")
        userCont += 1
    elif machinInput == tijeras and userInput == papel:
        print("Has perdido")
        machinCont += 1
else:
    print("Empate")

# Cada cierto tiempo quiero darle una vuelta hasta lograr una forma más elegante.

print("Esto solo ha sido un calentamiento. \n¿Qué te parece? ¿Jugamos hasta que alguien supere al otro por dos?")
# Se puede hacer muy cansino. Tal vez lo cambie al primero que llegue a 3.

def partida():

    global userCont
    global machinCont

    print("Piedra...")
    print("Papel...")
    print("¡Tijeras!")

    pptAlea = randint(0, 2)
    if pptAlea == 0:
        machinInput = piedra
    elif pptAlea == 1:
        machinInput = papel
    else:
        machinInput = tijeras

    userElige = input("Elige: \n>>>")
    userInput = userElige.lower()

    while userInput not in opciones:
        print("Escríbelo otra vez, por favor.")
        userInput = input(">>>").lower()

    print("Yo he elegido " + machinInput + ".")
    print("Y tú has elegido " + userInput + ".")

    if userInput != machinInput:
        if machinInput == piedra and userInput == papel:
            print("Has ganado")
            userCont = userCont+1
            comprobante(machinCont, userCont)
        elif machinInput == piedra and userInput == tijeras:
            print("Has perdido")
            machinCont = machinCont+1
            comprobante(machinCont, userCont)
        elif machinInput == papel and userInput == tijeras:
            print("Has ganado")
            userCont = userCont+1
            comprobante(machinCont, userCont)
        elif machinInput == papel and userInput == piedra:
            print("Has perdido")
            machinCont = machinCont+1
            comprobante(machinCont, userCont)
        elif machinInput == tijeras and userInput == piedra:
            print("Has ganado")
            userCont = userCont+1
            comprobante(machinCont, userCont)
        elif machinInput == tijeras and userInput == papel:
            print("Has perdido")
            machinCont = machinCont+1
            comprobante(machinCont, userCont)
    else:
        print("Empate")
        comprobante(machinCont, userCont)

def comprobante(machinCont, userCont):
    print(f"Yo he ganado: {machinCont}.")
    print(f"Tú has ganado: {userCont}.")

    if abs(userCont - machinCont) != 2:
        partida()
    elif userCont == (machinCont + 2):
        print("Está bien, no hay quien pueda contigo.")
    elif machinCont == (userCont + 2):
        print("Has jugado bien. Para un ser humano, jijiji.")

partida()
